# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
sample=np.random.choice([1,2,3,4,5,6],100)

# %%
from collections import Counter

# %%
c=Counter(sample)
print 'Число выпадений каждой из сторон:'
print c
print type(c)
# Out:
# Число выпадений каждой из сторон:
# Counter({6: 21, 4: 19, 1: 17, 3: 16, 5: 15, 2: 12})
# <class 'collections.Counter'>

# %%
print 'Вероятности каждой из сторон:'
print({k:v/100. for k,v in c.items()})
# Out:
# Вероятности каждой из сторон:
# {1: 0.17, 2: 0.12, 3: 0.16, 4: 0.19, 5: 0.15, 6: 0.21}

# %%
norm_rv=sts.norm(0,1)
sample=norm_rv.rvs(100)

# %%
x=np.linspace(-4,4,100)
cdf=norm_rv.cdf(x)
plt.plot(x,cdf,label='theoretical CDF')

from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(sample)
plt.step(ecdf.x, ecdf.y,label='ECDF')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %%
plt.hist(sample,normed=True)
plt.grid(True)
plt.ylabel('fraction of samples')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,u'$x$')

# %%
plt.hist(sample,bins=3,normed=True)
plt.ylabel('fraction of samples')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,u'$x$')

# %%
plt.hist(sample,bins=40,normed=True)
plt.ylabel('fraction of samples')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,u'$x$')

# %%
df=pd.DataFrame(sample,columns=['KDE'])
df
# Out:
#          KDE
# 0   0.206277
# 1   0.161825
# 2  -1.856758
# 3  -1.370346
# 4  -0.561544
# 5  -0.673434
# 6   0.232187
# 7   0.223490
# 8  -0.896712
# 9  -0.556057
# 10 -1.125203
# 11 -0.868131
# 12 -1.429785
# 13 -1.472917
# 14 -0.947805
# 15  0.693865
# 16  0.644652
# 17  1.620472
# 18  0.228073
# 19 -1.416646
# 20  2.329940
# 21  0.457868
# 22  0.918918
# 23  1.317747
# 24 -1.198376
# 25 -0.985156
# 26  0.335418
# 27 -0.126852
# 28  0.034838
# 29 -0.696564
# ..       ...
# 70 -0.729870
# 71 -1.227035
# 72 -0.300464
# 73 -1.365649
# 74 -0.261062
# 75 -0.155866
# 76  2.439996
# 77 -1.321226
# 78  0.118452
# 79  0.079698
# 80  0.127036
# 81 -1.207652
# 82  1.216994
# 83  0.283980
# 84 -0.275308
# 85 -0.383753
# 86  0.095845
# 87 -0.066065
# 88  0.236459
# 89 -0.414990
# 90  0.293321
# 91 -0.815366
# 92 -0.046445
# 93  0.761706
# 94 -0.453810
# 95 -0.275632
# 96  0.596001
# 97 -0.495609
# 98 -1.169300
# 99  0.646522
#
# [100 rows x 1 columns]

# %%
ax=df.plot(kind='density')
x=np.linspace(-4,4,100)
pdf=norm_rv.pdf(x)
plt.plot(x,pdf,label='theoretical pdf',alpha=0.8)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,u'$x$')
